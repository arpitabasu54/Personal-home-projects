# %%
## hOW TO READ A PARQUET FILE!!!
# !pip install fastparquet
import pandas as pd 
data= pd.read_parquet('D:/top mentor/python assignments and files/est_hourly.paruqet', engine='fastparquet')
data
# Out:
# ...
#                          AEP    COMED  DAYTON    DEOK      DOM     DUQ  \
# Datetime
# 1998-12-31 01:00:00      NaN      NaN     NaN     NaN      NaN     NaN
# 1998-12-31 02:00:00      NaN      NaN     NaN     NaN      NaN     NaN
# 1998-12-31 03:00:00      NaN      NaN     NaN     NaN      NaN     NaN
# 1998-12-31 04:00:00      NaN      NaN     NaN     NaN      NaN     NaN
# 1998-12-31 05:00:00      NaN      NaN     NaN     NaN      NaN     NaN
# ...                      ...      ...     ...     ...      ...     ...
# 2018-01-01 20:00:00  21089.0  13858.0  2732.0  4426.0  18418.0  1962.0
# 2018-01-01 21:00:00  20999.0  13758.0  2724.0  4419.0  18567.0  1940.0
# 2018-01-01 22:00:00  20820.0  13627.0  2664.0  4355.0  18307.0  1891.0
# 2018-01-01 23:00:00  20415.0  13336.0  2614.0  4224.0  17814.0  1820.0
# 2018-01-02 00:00:00  19993.0  12816.0  2552.0  4100.0  17428.0  1721.0
#
#                        EKPC      FE  NI     PJME    PJMW  PJM_Load
# Datetime
# ...

# %%
data= data.reset_index()
data.duplicated().sum()   ##to know the total of dupliactes & if duplicate values are to be found #data[data.duplicated().sum()]
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178262 entries, 0 to 178261
# Data columns (total 13 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Datetime  178262 non-null  datetime64[ns]
#  1   AEP       121273 non-null  float64
#  2   COMED     66497 non-null   float64
#  3   DAYTON    121275 non-null  float64
#  4   DEOK      57739 non-null   float64
#  5   DOM       116189 non-null  float64
#  6   DUQ       119068 non-null  float64
#  7   EKPC      45334 non-null   float64
#  8   FE        62874 non-null   float64
#  9   NI        58450 non-null   float64
#  10  PJME      145366 non-null  float64
#  11  PJMW      143206 non-null  float64
#  12  PJM_Load  32896 non-null   float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 17.7 MB

# %%
## hOW TO READ AN Excel FILE!!!-------- Sales data.xlsx 

import pandas as pd
data1 = pd.read_excel('D:/top mentor/python assignments and files/SalesData.xlsx')
data1
# Out:
#                   Sales Report   Unnamed: 1  Unnamed: 2      Unnamed: 3  \
# 0       Extraction: 14/03/2021          NaN         NaN             NaN
# 1                          NaN          NaN         NaN             NaN
# 2                          NaN          NaN         NaN             NaN
# 3                    OrderDate  OrderNumber  ProductKey  SalespersonKey
# 4          2019-01-12 00:00:00      1492762        1420             265
# ...                        ...          ...         ...             ...
# 260095     2021-03-12 00:00:00      2174271         258             102
# 260096     2021-03-12 00:00:00      2174271         235             102
# 260097     2021-03-12 00:00:00      2174271         202             102
# 260098     2021-03-12 00:00:00      2174490        2103             669
# 260099     2021-03-13 00:00:00      2172961         257             215
#
#             Unnamed: 4      Unnamed: 5       Unnamed: 6   Unnamed: 7  \
# ...

# %%
#& THEN Analyse the Data, two extra columns--- 1) Total sales(Qty* unit price) 2)avg , mean, median, group by, agg, etc etc

# %%
w= data1.drop([0,1,2])
w
# Out:
#                Sales Report   Unnamed: 1  Unnamed: 2      Unnamed: 3  \
# 3                 OrderDate  OrderNumber  ProductKey  SalespersonKey
# 4       2019-01-12 00:00:00      1492762        1420             265
# 5       2019-01-12 00:00:00      1492762        1073             265
# 6       2019-01-12 00:00:00      1492762         264             265
# 7       2019-01-13 00:00:00      1492719        1154             265
# ...                     ...          ...         ...             ...
# 260095  2021-03-12 00:00:00      2174271         258             102
# 260096  2021-03-12 00:00:00      2174271         235             102
# 260097  2021-03-12 00:00:00      2174271         202             102
# 260098  2021-03-12 00:00:00      2174490        2103             669
# 260099  2021-03-13 00:00:00      2172961         257             215
#
#             Unnamed: 4      Unnamed: 5       Unnamed: 6   Unnamed: 7  \
# ...

# %%
w= w.rename(columns= w.loc[3])
w= w.drop([3])
w
# Out:
#                   OrderDate OrderNumber ProductKey SalespersonKey  \
# 4       2019-01-12 00:00:00     1492762       1420            265
# 5       2019-01-12 00:00:00     1492762       1073            265
# 6       2019-01-12 00:00:00     1492762        264            265
# 7       2019-01-13 00:00:00     1492719       1154            265
# 8       2019-01-13 00:00:00     1492719       1527            265
# ...                     ...         ...        ...            ...
# 260095  2021-03-12 00:00:00     2174271        258            102
# 260096  2021-03-12 00:00:00     2174271        235            102
# 260097  2021-03-12 00:00:00     2174271        202            102
# 260098  2021-03-12 00:00:00     2174490       2103            669
# 260099  2021-03-13 00:00:00     2172961        257            215
#
#            Salesperson      Supervisor          Manager      Channel Quantity  \
# 4           Julio Lima  Diogo Carvalho  Gabriel Azevedo  Distributor        6
# ...

# %%
T=w.tail(n=8)
T
# Out:
#                   OrderDate OrderNumber ProductKey SalespersonKey  \
# 260092  2021-03-12 00:00:00     2174271       1166            102
# 260093  2021-03-12 00:00:00     2174271        157            102
# 260094  2021-03-12 00:00:00     2174271        256            102
# 260095  2021-03-12 00:00:00     2174271        258            102
# 260096  2021-03-12 00:00:00     2174271        235            102
# 260097  2021-03-12 00:00:00     2174271        202            102
# 260098  2021-03-12 00:00:00     2174490       2103            669
# 260099  2021-03-13 00:00:00     2172961        257            215
#
#            Salesperson      Supervisor        Manager Channel Quantity  \
# 260092  Gustavo Barros     Emily Rocha  Victor Castro  Retail        3
# 260093  Gustavo Barros     Emily Rocha  Victor Castro  Retail        3
# 260094  Gustavo Barros     Emily Rocha  Victor Castro  Retail        2
# 260095  Gustavo Barros     Emily Rocha  Victor Castro  Retail        2
# ...

# %%
T1=T.groupby(['Salesperson','Quantity']).agg(['min','max','sum','mean',])
T1
# Out:
#                         OrderNumber                                      \
#                                 min                                 max
#                                 min      max      sum     mean      min
# Salesperson    Quantity
# Carla Ferreira 6            2172961  2172961  2172961  2172961  2172961
# Gustavo Barros 2            2174271  2174271  2174271  2174271  2174271
#                3            2174271  2174271  2174271  2174271  2174271
#                24           2174271  2174271  2174271  2174271  2174271
#                30           2174271  2174271  2174271  2174271  2174271
# Kaua Araujo    3            2174490  2174490  2174490  2174490  2174490
#
#                                                                       ...  \
#                                                         sum           ...
#                              max      sum     mean      min      max  ...
# ...

# %%
w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 260096 entries, 4 to 260099
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   OrderDate       260096 non-null  object
#  1   OrderNumber     260096 non-null  object
#  2   ProductKey      260096 non-null  object
#  3   SalespersonKey  260096 non-null  object
#  4   Salesperson     260096 non-null  object
#  5   Supervisor      260096 non-null  object
#  6   Manager         260096 non-null  object
#  7   Channel         260096 non-null  object
#  8   Quantity        260096 non-null  object
#  9   UnitPrice       260096 non-null  object
# dtypes: object(10)
# memory usage: 21.8+ MB

# %%
((w['Salesperson'].str.startswith('J'))&(w['Salesperson'].str.endswith('a')))
# Out:
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
#           ...
# 260095    False
# 260096    False
# 260097    False
# 260098    False
# 260099    False
# Name: Salesperson, Length: 260096, dtype: bool

# %%
w
# Out:
#                   OrderDate OrderNumber ProductKey SalespersonKey  \
# 4       2019-01-12 00:00:00     1492762       1420            265
# 5       2019-01-12 00:00:00     1492762       1073            265
# 6       2019-01-12 00:00:00     1492762        264            265
# 7       2019-01-13 00:00:00     1492719       1154            265
# 8       2019-01-13 00:00:00     1492719       1527            265
# ...                     ...         ...        ...            ...
# 260095  2021-03-12 00:00:00     2174271        258            102
# 260096  2021-03-12 00:00:00     2174271        235            102
# 260097  2021-03-12 00:00:00     2174271        202            102
# 260098  2021-03-12 00:00:00     2174490       2103            669
# 260099  2021-03-13 00:00:00     2172961        257            215
#
#            Salesperson      Supervisor          Manager      Channel Quantity  \
# 4           Julio Lima  Diogo Carvalho  Gabriel Azevedo  Distributor        6
# ...

# %%
r=w.set_index('Channel').head(n=20)
r
# Out:
#                        OrderDate OrderNumber ProductKey SalespersonKey  \
# Channel
# Distributor  2019-01-12 00:00:00     1492762       1420            265
# Distributor  2019-01-12 00:00:00     1492762       1073            265
# Distributor  2019-01-12 00:00:00     1492762        264            265
# Distributor  2019-01-13 00:00:00     1492719       1154            265
# Distributor  2019-01-13 00:00:00     1492719       1527            265
# Distributor  2019-01-13 00:00:00     1492719       1862            265
# Distributor  2019-01-13 00:00:00     1492719        438            265
# Distributor  2019-01-13 00:00:00     1492719       1468            265
# Distributor  2019-01-13 00:00:00     1492719       1534            265
# Distributor  2019-01-13 00:00:00     1492719        203            265
# Distributor  2019-01-13 00:00:00     1492719       1216            265
# Distributor  2019-01-13 00:00:00     1492719       1132            265
# ...

# %%
w['Total_Sales'] = w['Quantity'] * w['UnitPrice']  ## creating new column to the dataset after dropping unnecessary rows
w
# Out:
#                   OrderDate OrderNumber ProductKey SalespersonKey  \
# 4       2019-01-12 00:00:00     1492762       1420            265
# 5       2019-01-12 00:00:00     1492762       1073            265
# 6       2019-01-12 00:00:00     1492762        264            265
# 7       2019-01-13 00:00:00     1492719       1154            265
# 8       2019-01-13 00:00:00     1492719       1527            265
# ...                     ...         ...        ...            ...
# 260095  2021-03-12 00:00:00     2174271        258            102
# 260096  2021-03-12 00:00:00     2174271        235            102
# 260097  2021-03-12 00:00:00     2174271        202            102
# 260098  2021-03-12 00:00:00     2174490       2103            669
# 260099  2021-03-13 00:00:00     2172961        257            215
#
#            Salesperson      Supervisor          Manager      Channel Quantity  \
# 4           Julio Lima  Diogo Carvalho  Gabriel Azevedo  Distributor        6
# ...

# %%
pwd
# Out:
# 'C:\\Users\\MY PC'
